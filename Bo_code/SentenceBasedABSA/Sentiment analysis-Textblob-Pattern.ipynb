# %%
# !ls
# Out:
#  aspects_B002XTCAXG.csv   B07TJ41TMC.csv
#  B000LJWV4S.csv		  B07TZ3BMKW.csv
#  B002XTCAXG.csv		  B07X5TTTJT.csv
#  B00GZYNX8G.csv		  requirements.txt
#  B00OYKXTDW.csv		  Sentence_Partition.ipynb
#  B010ESCLHW.csv		 'Sentiment analysis.ipynb'
#  B01J8B219O.csv		 'Sentiment analysis-Textblob-NB-Copy1.ipynb'
#  B06VTLLC13.csv		 'Sentiment analysis-Textblob-NB.ipynb'
#  B07568DFCH.csv		 'Sentiment analysis-Textblob-pattern.ipynb'
#  B07DQKV38W.csv		  sentiment_aspects_B002XTCAXG.csv
#  B07G3SJPLZ.csv		  sentiment_B002XTCAXG.csv
#  B07JCFY3N4.csv

# %%
import pandas as pd
import numpy as np
import time
import nltk
from textblob import TextBlob
from textblob import Blobber
from textblob.sentiments import PatternAnalyzer
pa = Blobber(analyzer=PatternAnalyzer())

# %%
filename = "aspects_B002XTCAXG.csv"
df = pd.read_csv(filename)
print(f"Original shape: {df.shape}")
df = df.replace(np.nan,'')
df.head(3)
# Out:
# Original shape: (80, 8)
#    Unnamed: 0                                            reviews  \
# 0           0  this thing lights up the night sky! bought it ...
# 1           1  I own three Streamlight weapon-mounted lights,...
# 2           2  Great flashlight that is bright and lasts! Fir...
#
#                                                 size  \
# 0
# 1  i consider this flashlight to be a good size a...
# 2  it's well balanced in the hand, and not to hea...
#
#                                              quality  \
# 0
# 1  i own three streamlight weapon-mounted lights,...
# 2  as far as quality and durability, it has a sol...
#
#                                              battery  \
# 0
# 1  i bought this because i needed a rechargeable ...
# 2  depending on which you use, will depend on you...
#
#                                               design  \
# 0
# 1  i like the three intensity settings and the st...
# 2  it has three settings of power.but this is my ...
#
#                                                 beam price
# 0                this thing lights up the night sky!
# 1  i own three streamlight weapon-mounted lights,...
# 2  great flashlight that is bright and lasts!it h...

# %%
# df.apply(sid.polarity_scores)
def find_sentiment(sentence):
    return pa(sentence).sentiment[0]

# %%
start = time.time()
df.iloc[:,2:] = df.iloc[:,2:].applymap(find_sentiment)
end = time.time()
print(f"Took {end - start} seconds to match sentences into aspects.")
# Out:
# Took 0.08225750923156738 seconds to match sentences into aspects.

# %%
df
# Out:
#     Unnamed: 0                                            reviews      size  \
# 0            0  this thing lights up the night sky! bought it ...  0.000000
# 1            1  I own three Streamlight weapon-mounted lights,...  0.550000
# 2            2  Great flashlight that is bright and lasts! Fir...  0.183333
# 3            3  I bought mine back in 2012 with the piggyback ...  0.000000
# 4            4  I do home inspections and use my flashlight 5-...  0.000000
# ..         ...                                                ...       ...
# 75          75                                            Love it  0.000000
# 76          76  Best flashlight I have ever had. Although pric... -0.129167
# 77          77                           Love, love, love it!!!!!  0.000000
# 78          78  Good light but it did not come with the charge...  0.000000
# 79          79  I am in law enforecement and this light will f...  0.000000
#
#      quality   battery    design      beam     price
# 0   0.000000  0.000000  0.000000  0.000000  0.000000
# 1   0.383333  0.206000  0.350000  0.256481  0.000000
# 2   0.130000  0.422667 -0.225000  0.407333  0.000000
# 3   0.000000  0.143611  0.128889  0.268889  0.000000
# 4   0.000000  0.000000  0.229167  0.379167  0.000000
# ..       ...       ...       ...       ...       ...
# 75  0.000000  0.000000  0.000000  0.000000  0.000000
# 76  0.000000  0.000000  0.000000 -0.129167 -0.129167
# 77  0.000000  0.000000  0.000000  0.000000  0.000000
# 78  0.000000  0.000000  0.000000  0.000000  0.000000
# 79  0.000000  0.280000  0.280000  0.280000  0.000000
#
# [80 rows x 8 columns]
