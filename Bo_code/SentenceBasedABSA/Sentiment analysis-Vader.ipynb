# %%
# !ls

# %%
import pandas as pd
import numpy as np
import time
import nltk
#nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

# %%
filename = "sentence_partition.csv"
df = pd.read_csv(filename)
print(f"Original shape: {df.shape}")
df = df.replace(np.nan,'')
df.head(3)
# Out:
# Original shape: (80, 8)
#    Unnamed: 0                                            reviews  \
# 0           0  this thing lights up the night sky! bought it ...
# 1           1  I own three Streamlight weapon-mounted lights,...
# 2           2  Great flashlight that is bright and lasts! Fir...
#
#                                                 size  \
# 0
# 1  i consider this flashlight to be a good size a...
# 2  it's well balanced in the hand, and not to hea...
#
#                                              quality  \
# 0
# 1
# 2  as far as quality and durability, it has a sol...
#
#                                              battery  \
# 0
# 1  i bought this because i needed a rechargeable ...
# 2  depending on which you use, will depend on you...
#
#                                               design  \
# 0
# 1  i like the three intensity settings and the st...
# 2  it has three settings of power.but this is my ...
#
# ...

# %%
# df.apply(sid.polarity_scores)
def find_sentiment(sentence):
    return sid.polarity_scores(sentence)

# %%
df.iloc[:,2:] = df.iloc[:,2:].applymap(find_sentiment)

# %%
df
# Out:
#     Unnamed: 0                                            reviews  \
# 0            0  this thing lights up the night sky! bought it ...
# 1            1  I own three Streamlight weapon-mounted lights,...
# 2            2  Great flashlight that is bright and lasts! Fir...
# 3            3  I bought mine back in 2012 with the piggyback ...
# 4            4  I do home inspections and use my flashlight 5-...
# ..         ...                                                ...
# 75          75                                            Love it
# 76          76  Best flashlight I have ever had. Although pric...
# 77          77                           Love, love, love it!!!!!
# 78          78  Good light but it did not come with the charge...
# 79          79  I am in law enforecement and this light will f...
#
#                                                  size  \
# 0   {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound...
# 1   {'neg': 0.0, 'neu': 0.868, 'pos': 0.132, 'comp...
# ...

# %%
df.to_csv('sentiment_'+filename)
